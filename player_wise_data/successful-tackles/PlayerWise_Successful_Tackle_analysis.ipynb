# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import numpy as np
import pandas_profiling
import cufflinks as cf
cf.set_config_file(offline=True)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.read_csv('s7_succ_tackles.csv',index_col=0)

# %%
df.head()
# Out:
#                      name                    TEAM  machesplayed  \
# rank
# 1     Sandeep Kumar Dhull   Defender, Left Corner            20
# 1                   Sumit   Defender, Left Corner            18
# 3          Ravinder Pahal  Defender, Right Corner            20
# 3         Fazel Atrachali   Defender, Left Corner            19
# 5            Baldev Singh  Defender, Right Corner            20
#
#       successfultackles  total tackles
# rank
# 1                    60            133
# 1                    60            111
# 3                    57            132
# 3                    57            104
# 5                    54            105

# %%
df.dtypes
# Out:
# name                 object
# TEAM                 object
# machesplayed          int64
# successfultackles     int64
# total tackles         int64
# dtype: object

# %%
df['SuccfulTackle%'] = df['successfultackles']/df['total tackles']

# %%
df['averageTackle%'] = df['successfultackles']/df['machesplayed']

# %%
df
# Out:
#                              name                             TEAM  \
# rank
# 1             Sandeep Kumar Dhull            Defender, Left Corner
# 1                           Sumit            Defender, Left Corner
# 3                  Ravinder Pahal           Defender, Right Corner
# 3                 Fazel Atrachali            Defender, Left Corner
# 5                    Baldev Singh           Defender, Right Corner
# 6                 Vishal Bhardwaj                         Defender
# 7                    Rinku Narwal                         Defender
# 8                    Neeraj Kumar            Defender, Right Cover
# 9               Parvesh Bhainswal             Defender, Left Cover
# 9                PO Surjeet Singh            Defender, Right Cover
# 11                        Jaideep            Defender, Left Corner
# 11                          Sunil           Defender, Right Corner
# 13                   Nitesh Kumar                         Defender
# ...

# %%
df.corr().iplot(kind='heatmap',colorscale='ylgn')
# Out:
# <div>
#
#
#             <div id="cbf8e639-661b-4f89-b4f3-b3077ba92a03" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cbf8e639-661b-4f89-b4f3-b3077ba92a03")) {
#                     Plotly.newPlot(
#                         'cbf8e639-661b-4f89-b4f3-b3077ba92a03',
# ...

# %% [markdown]
# ### Finding players having successful tackle % > 0.5

# %%
tackle_var = df['SuccfulTackle%']>=0.5
df[tackle_var]
# Out:
#                          name                    TEAM  machesplayed  \
# rank
# 1                       Sumit   Defender, Left Corner            18
# 3             Fazel Atrachali   Defender, Left Corner            19
# 5                Baldev Singh  Defender, Right Corner            20
# 9           Parvesh Bhainswal    Defender, Left Cover            20
# 13               Nitesh Kumar                Defender            18
# 42                    More GB                  Raider            17
# 69              Surender Gill                  Raider            15
# 89     Siddharth Sirish Desai                  Raider            18
# 89                Sonu Jaglan                  Raider            15
# 102                   Gurdeep             All Rounder             2
# 102           Lalit Chaudhary                  Raider             4
# 102               Selvamani K                  Raider             7
# 120   Ravindra Ramesh Kumawat                  Raider             3
# ...
