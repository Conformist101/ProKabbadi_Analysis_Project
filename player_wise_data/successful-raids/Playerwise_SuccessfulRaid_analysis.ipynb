# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import numpy as np
import pandas_profiling
import cufflinks as cf
cf.set_config_file(offline=True)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.read_csv('s7_succ_raids.csv',index_col=0)

# %%
df.head()
# Out:
#                         name    TEAM  machesplayed  successfulraids  \
# rank
# 1               Naveen Kumar  Raider            20              213
# 2             Pardeep Narwal  Raider            19              190
# 3       Pawan Kumar Sehrawat  Raider            19              187
# 4             Maninder Singh  Raider            20              171
# 5     Siddharth Sirish Desai  Raider            18              143
#
#       total raids
# rank
# 1             408
# 2             383
# 3             343
# 4             318
# 5             272

# %%
df.dtypes
# Out:
# name               object
# TEAM               object
# machesplayed        int64
# successfulraids     int64
# total raids         int64
# dtype: object

# %%
df['SuccfulRaid%'] = df['successfulraids']/df['total raids']

# %%
df['averageRaid%'] = df['successfulraids']/df['machesplayed']

# %%
df
# Out:
#                              name                             TEAM  \
# rank
# 1                    Naveen Kumar                           Raider
# 2                  Pardeep Narwal                           Raider
# 3            Pawan Kumar Sehrawat                           Raider
# 4                  Maninder Singh                           Raider
# 5          Siddharth Sirish Desai                           Raider
# 6                  Vikash Kandola                           Raider
# 7              Deepak Niwas Hooda                      All Rounder
# 8                  Abhishek Singh                           Raider
# 9                 Rahul Chaudhari                           Raider
# 10                    Rohit Gulia                      All Rounder
# 11                 V. Ajith Kumar                           Raider
# 12                        Manjeet                           Raider
# 13                  Pankaj Mohite                           Raider
# ...

# %%
df.corr().iplot(kind='heatmap',colorscale='ylgn')
# Out:
# <div>
#
#
#             <div id="847239b1-67ca-4476-8b5d-cf50e53e0c63" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("847239b1-67ca-4476-8b5d-cf50e53e0c63")) {
#                     Plotly.newPlot(
#                         '847239b1-67ca-4476-8b5d-cf50e53e0c63',
# ...

# %% [markdown]
# ### Finding players having successful raid % > 0.5

# %%
raid_var = df['SuccfulRaid%']>=0.5
df[raid_var]
# Out:
#                         name                   TEAM  machesplayed  \
# rank
# 1               Naveen Kumar                 Raider            20
# 3       Pawan Kumar Sehrawat                 Raider            19
# 4             Maninder Singh                 Raider            20
# 5     Siddharth Sirish Desai                 Raider            18
# 67                    Ankush                 Raider             3
# 67     Victor Onyango Obiero            All Rounder             3
# 73             Rakesh Narwal                 Raider             2
# 86               Chand Singh  Defender, Left Corner             9
# 86            Vikas Chhillar                 Raider             1
# 86            Saurabh Nandal  Defender, Left Corner            18
#
#       successfulraids  total raids  SuccfulRaid%  averageRaid%
# rank
# 1                 213          408      0.522059     10.650000
# 3                 187          343      0.545190      9.842105
# ...
