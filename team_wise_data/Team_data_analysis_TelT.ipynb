# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import numpy as np
import pandas_profiling
import cufflinks as cf
cf.set_config_file(offline=True)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('Telegu-Titans.csv',index_col=0)

# %%
df.head()
# Out:
#                     OVERALL  SEASON 7  SEASON 6  SEASON 5  SEASON 4  SEASON 3  \
# SEASONS
# MATCHES PLAYED        123.0      16.0      23.0      22.0      14.0      16.0
# WINS                   76.0       8.0      15.0      10.0       7.0      13.0
# DRAWS                   7.0       1.0       2.0       0.0       1.0       0.0
# LOSSES                 40.0       7.0       6.0      12.0       6.0       3.0
# FINISHING POSITION      0.0       5.0       2.0       4.0       4.0       1.0
#
#                     SEASON 2  SEASON 1      Team-name
# SEASONS
# MATCHES PLAYED          16.0      16.0  telugu-titans
# WINS                    14.0       9.0  telugu-titans
# DRAWS                    0.0       3.0  telugu-titans
# LOSSES                   2.0       4.0  telugu-titans
# FINISHING POSITION       1.0       2.0  telugu-titans

# %%
df1 = df.transpose()

# %%
df2 = df1.apply(pd.to_numeric, errors='coerce')

# %%
df2
# Out:
# SEASONS    MATCHES PLAYED  WINS  DRAWS  LOSSES  FINISHING POSITION  \
# OVERALL             123.0  76.0    7.0    40.0                 0.0
# SEASON 7             16.0   8.0    1.0     7.0                 5.0
# SEASON 6             23.0  15.0    2.0     6.0                 2.0
# SEASON 5             22.0  10.0    0.0    12.0                 4.0
# SEASON 4             14.0   7.0    1.0     6.0                 4.0
# SEASON 3             16.0  13.0    0.0     3.0                 1.0
# SEASON 2             16.0  14.0    0.0     2.0                 1.0
# SEASON 1             16.0   9.0    3.0     4.0                 2.0
# Team-name             NaN   NaN    NaN     NaN                 NaN
#
# SEASONS    TOTAL RAIDS  SUCCESSFUL RAIDS  UNSUCCESSFUL RAID  EMPTY RAIDS  \
# OVERALL         5187.0            1753.0             1121.0       2313.0
# SEASON 7         646.0             208.0              148.0        290.0
# SEASON 6         978.0             372.0              196.0        410.0
# SEASON 5         963.0             322.0              219.0        422.0
# SEASON 4         594.0             188.0              131.0        275.0
# SEASON 3         685.0             206.0              139.0        340.0
# SEASON 2         697.0             187.0              154.0        356.0
# SEASON 1         624.0             270.0              134.0        220.0
# Team-name          NaN               NaN                NaN          NaN
#
# SEASONS    SUCCESS RAID %          ...           RAID BONUS POINTS  \
# OVERALL              0.43          ...                       482.0
# SEASON 7             0.41          ...                        53.0
# SEASON 6             0.47          ...                        87.0
# SEASON 5             0.44          ...                       121.0
# SEASON 4             0.38          ...                        63.0
# SEASON 3             0.37          ...                        42.0
# SEASON 2             0.34          ...                        31.0
# SEASON 1             0.56          ...                        85.0
# Team-name             NaN          ...                         NaN
#
# SEASONS    TOTAL RAID POINTS  TOTAL TACKLES  SUCCESSFUL TACKLES  \
# OVERALL               2208.0         2826.0              1193.0
# SEASON 7               266.0          334.0               145.0
# SEASON 6               459.0          558.0               274.0
# SEASON 5               419.0          539.0               176.0
# SEASON 4               227.0          293.0               110.0
# SEASON 3               253.0          329.0               163.0
# SEASON 2               237.0          364.0               180.0
# SEASON 1               347.0          409.0               145.0
# Team-name                NaN            NaN                 NaN
#
# SEASONS    UNSUCCESFUL TACKLES  SUCCESSFUL TACKLE %  NO. OF SUPER TACKLES  \
# OVERALL                 1633.0                 0.46                 102.0
# SEASON 7                 189.0                 0.48                  16.0
# SEASON 6                 284.0                 0.52                  15.0
# SEASON 5                 363.0                 0.37                  26.0
# SEASON 4                 183.0                 0.41                  11.0
# SEASON 3                 166.0                 0.51                   6.0
# SEASON 2                 184.0                 0.54                  16.0
# SEASON 1                 264.0                 0.38                  12.0
# Team-name                  NaN                  NaN                   NaN
#
# SEASONS    ALL OUTS INFLICTED  TOTAL ALL OUT POINTS  TOTAL DEFENCE POINTS
# OVERALL                 167.0                 334.0                1293.0
# SEASON 7                 22.0                  44.0                 159.0
# SEASON 6                 41.0                  82.0                 289.0
# SEASON 5                 21.0                  42.0                 202.0
# SEASON 4                 15.0                  30.0                 121.0
# SEASON 3                 27.0                  54.0                 169.0
# SEASON 2                 20.0                  40.0                 196.0
# SEASON 1                 21.0                  42.0                 157.0
# Team-name                 NaN                   NaN                   NaN
#
# [9 rows x 22 columns]

# %%
df2['WIN%'] = df2['WINS']/df2['MATCHES PLAYED']
df2['DRAW%'] = df2['DRAWS']/df2['MATCHES PLAYED']
df2['LOSS%'] = df2['LOSSES']/df2['MATCHES PLAYED']
df2['WIN-LOSS%'] = df2['WINS']/df2['LOSSES']

# %%
df2.dtypes
# Out:
# SEASONS
# MATCHES PLAYED          float64
# WINS                    float64
# DRAWS                   float64
# LOSSES                  float64
# FINISHING POSITION      float64
# TOTAL RAIDS             float64
# SUCCESSFUL RAIDS        float64
# UNSUCCESSFUL RAID       float64
# EMPTY RAIDS             float64
# SUCCESS RAID %          float64
# NO. OF SUPER RAIDS      float64
# RAID TOUCH POINTS       float64
# RAID BONUS POINTS       float64
# TOTAL RAID POINTS       float64
# TOTAL TACKLES           float64
# SUCCESSFUL TACKLES      float64
# UNSUCCESFUL TACKLES     float64
# SUCCESSFUL TACKLE %     float64
# NO. OF SUPER TACKLES    float64
# ALL OUTS INFLICTED      float64
# TOTAL ALL OUT POINTS    float64
# TOTAL DEFENCE POINTS    float64
# WIN%                    float64
# DRAW%                   float64
# LOSS%                   float64
# WIN-LOSS%               float64
# dtype: object

# %%
df2['UNSUCCESSFUL RAID%'] = df2['UNSUCCESSFUL RAID']/df2['TOTAL RAIDS']
df2['EMPTY RAID%'] = df2['EMPTY RAIDS']/df2['TOTAL RAIDS']
df2['AVG_RAID_TOUCH_POINT'] = df2['RAID TOUCH POINTS']/df2['MATCHES PLAYED']
df2['AVG_RAID_BONUS_POINT'] = df2['RAID BONUS POINTS']/df2['MATCHES PLAYED']
df2['UNSUCCESSFUL TACKLE%'] = df2['UNSUCCESFUL TACKLES']/df2['TOTAL TACKLES']
df2['AVG_ALL_OUTS'] = df2['ALL OUTS INFLICTED']/df2['MATCHES PLAYED']

# %%
df6 = df2.drop(['MATCHES PLAYED','WINS','DRAWS','LOSSES','SUCCESSFUL RAIDS','UNSUCCESSFUL RAID','EMPTY RAIDS','NO. OF SUPER RAIDS','RAID TOUCH POINTS','RAID BONUS POINTS','TOTAL RAID POINTS','TOTAL TACKLES','SUCCESSFUL TACKLES','UNSUCCESFUL TACKLES','ALL OUTS INFLICTED','TOTAL ALL OUT POINTS'],axis=1)

# %%
df6 = df6.drop(['Team-name'],axis=0)
df6
# Out:
# SEASONS   FINISHING POSITION  TOTAL RAIDS  SUCCESS RAID %  \
# OVERALL                  0.0       5187.0            0.43
# SEASON 7                 5.0        646.0            0.41
# SEASON 6                 2.0        978.0            0.47
# SEASON 5                 4.0        963.0            0.44
# SEASON 4                 4.0        594.0            0.38
# SEASON 3                 1.0        685.0            0.37
# SEASON 2                 1.0        697.0            0.34
# SEASON 1                 2.0        624.0            0.56
#
# SEASONS   SUCCESSFUL TACKLE %  NO. OF SUPER TACKLES  TOTAL DEFENCE POINTS  \
# OVERALL                  0.46                 102.0                1293.0
# SEASON 7                 0.48                  16.0                 159.0
# SEASON 6                 0.52                  15.0                 289.0
# SEASON 5                 0.37                  26.0                 202.0
# SEASON 4                 0.41                  11.0                 121.0
# SEASON 3                 0.51                   6.0                 169.0
# SEASON 2                 0.54                  16.0                 196.0
# SEASON 1                 0.38                  12.0                 157.0
#
# SEASONS       WIN%     DRAW%     LOSS%  WIN-LOSS%  UNSUCCESSFUL RAID%  \
# OVERALL   0.617886  0.056911  0.325203   1.900000            0.216117
# SEASON 7  0.500000  0.062500  0.437500   1.142857            0.229102
# SEASON 6  0.652174  0.086957  0.260870   2.500000            0.200409
# SEASON 5  0.454545  0.000000  0.545455   0.833333            0.227414
# SEASON 4  0.500000  0.071429  0.428571   1.166667            0.220539
# SEASON 3  0.812500  0.000000  0.187500   4.333333            0.202920
# SEASON 2  0.875000  0.000000  0.125000   7.000000            0.220947
# SEASON 1  0.562500  0.187500  0.250000   2.250000            0.214744
#
# SEASONS   EMPTY RAID%  AVG_RAID_TOUCH_POINT  AVG_RAID_BONUS_POINT  \
# OVERALL      0.445922             14.032520              3.918699
# SEASON 7     0.448916             13.312500              3.312500
# SEASON 6     0.419223             16.173913              3.782609
# SEASON 5     0.438214             13.545455              5.500000
# SEASON 4     0.462963             11.714286              4.500000
# SEASON 3     0.496350             13.187500              2.625000
# SEASON 2     0.510760             12.875000              1.937500
# SEASON 1     0.352564             16.375000              5.312500
#
# SEASONS   UNSUCCESSFUL TACKLE%  AVG_ALL_OUTS
# OVERALL               0.577849      1.357724
# SEASON 7              0.565868      1.375000
# SEASON 6              0.508961      1.782609
# SEASON 5              0.673469      0.954545
# SEASON 4              0.624573      1.071429
# SEASON 3              0.504559      1.687500
# SEASON 2              0.505495      1.250000
# SEASON 1              0.645477      1.312500

# %%
df6.dtypes
# Out:
# SEASONS
# FINISHING POSITION      float64
# TOTAL RAIDS             float64
# SUCCESS RAID %          float64
# SUCCESSFUL TACKLE %     float64
# NO. OF SUPER TACKLES    float64
# TOTAL DEFENCE POINTS    float64
# WIN%                    float64
# DRAW%                   float64
# LOSS%                   float64
# WIN-LOSS%               float64
# UNSUCCESSFUL RAID%      float64
# EMPTY RAID%             float64
# AVG_RAID_TOUCH_POINT    float64
# AVG_RAID_BONUS_POINT    float64
# UNSUCCESSFUL TACKLE%    float64
# AVG_ALL_OUTS            float64
# dtype: object

# %%
df6.corr().iplot(kind='heatmap',colorscale='ylgn')
# Out:
# <div>
#
#
#             <div id="b22400a8-c952-4891-85ce-5aecedae98b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b22400a8-c952-4891-85ce-5aecedae98b2")) {
#                     Plotly.newPlot(
#                         'b22400a8-c952-4891-85ce-5aecedae98b2',
#                         [{"colorscale": [[0.0, "rgb(255,255,229)"], [0.125, "rgb(247,252,185)"], [0.25, "rgb(217,240,163)"], [0.375, "rgb(173,221,142)"], [0.5, "rgb(120,198,121)"], [0.625, "rgb(65,171,93)"], [0.75, "rgb(35,132,67)"], [0.875, "rgb(0,104,55)"], [1.0, "rgb(0,69,41)"]], "type": "heatmap", "uid": "ddac1489-dff1-42a3-9e59-59b6480432bc", "x": ["FINISHING POSITION", "TOTAL RAIDS", "SUCCESS RAID %", "SUCCESSFUL TACKLE %", "NO. OF SUPER TACKLES", "TOTAL DEFENCE POINTS", "WIN%", "DRAW%", "LOSS%", "WIN-LOSS%", "UNSUCCESSFUL RAID%", "EMPTY RAID%", "AVG_RAID_TOUCH_POINT", "AVG_RAID_BONUS_POINT", "UNSUCCESSFUL TACKLE%", "AVG_ALL_OUTS"], "y": ["FINISHING POSITION", "TOTAL RAIDS", "SUCCESS RAID %", "SUCCESSFUL TACKLE %", "NO. OF SUPER TACKLES", "TOTAL DEFENCE POINTS", "WIN%", "DRAW%", "LOSS%", "WIN-LOSS%", "UNSUCCESSFUL RAID%", "EMPTY RAID%", "AVG_RAID_TOUCH_POINT", "AVG_RAID_BONUS_POINT", "UNSUCCESSFUL TACKLE%", "AVG_ALL_OUTS"], "z": [[1.0, -0.5422346637392272, 0.029424494316824902, -0.42822395345984954, -0.46406165345820277, -0.5724846227791084, -0.7315934397528018, 0.0538236877411041, 0.7631806413398002, -0.6072674488005226, 0.6011366501481896, -0.1504222167098641, -0.27005535140955933, 0.38847869017275916, 0.4836530101532957, -0.4401578147176341], [-0.5422346637392272, 1.0, 0.046503514907541815, 0.011475452988757693, 0.989809397454553, 0.9978326552036388, -0.019504820420998877, -0.03343378560132246, 0.035889743088707356, -0.1570618118172361, -0.036624941718015704, -0.018190634728326664, 0.06821005792715105, 0.03970535562021664, 0.010458477668538718, 0.026657490076445096], [0.029424494316824902, 0.046503514907541815, 1.0, -0.5429034716800467, 0.05096901760614466, 0.0522090314818517, -0.46240745112845977, 0.8356866648450796, 0.1250284356540823, -0.464960739991988, -0.15993282953314142, -0.9855780532123458, 0.8603259353297517, 0.7193651303747891, 0.48871963722178874, 0.07896079718602966], [-0.42822395345984954, 0.011475452988757693, -0.5429034716800467, 1.0, -0.05529614328152173, 0.06140639403362653, 0.7899505830104783, -0.39900555753541356, -0.6721060353638993, 0.69659695495191, -0.43628813882706075, 0.6067969658900878, -0.06756919636670551, -0.9300810190654631, -0.9863831612996738, 0.6869184599309752], [-0.46406165345820277, 0.989809397454553, 0.05096901760614466, -0.05529614328152173, 1.0, 0.9832356495798729, -0.09251731470698857, -0.051837610912034024, 0.12265251966802157, -0.19589005679866606, 0.09292631869098376, -0.031614927189452954, 0.03835332746623526, 0.09093200909008146, 0.09580522475601841, -0.08896385928532133], [-0.5724846227791084, 0.9978326552036388, 0.0522090314818517, 0.06140639403362653, 0.9832356495798729, 1.0, 0.019717275545026714, -0.021045028616891153, -0.011834355932452556, -0.1219410681137735, -0.07666652126764938, -0.019335628185798325, 0.1036540830144724, 0.004342552700988125, -0.04025160621398824, 0.0773166626233237], [-0.7315934397528018, -0.019504820420998877, -0.46240745112845977, 0.7899505830104783, -0.09251731470698857, 0.019717275545026714, 1.0, -0.371553879120454, -0.9103495200193834, 0.9522904466546187, -0.5125211946333055, 0.5711837293570537, -0.04459754251886682, -0.829886960578514, -0.821005747890662, 0.5076444338539325], [0.0538236877411041, -0.03343378560132246, 0.8356866648450796, -0.39900555753541356, -0.051837610912034024, -0.021045028616891153, -0.371553879120454, 1.0, -0.04597010626506043, -0.355343916143196, -0.14877229138900913, -0.878269569760366, 0.6688011392253911, 0.5113902979000942, 0.3461849675197801, 0.10680714042548822], [0.7631806413398002, 0.035889743088707356, 0.1250284356540823, -0.6721060353638993, 0.12265251966802157, -0.011834355932452556, -0.9103495200193834, -0.04597010626506043, 1.0, -0.866241077625062, 0.6177728231755621, -0.2230870790371775, -0.25013311638049535, 0.6649807765798361, 0.7290652889324415, -0.593819569457696], [-0.6072674488005226, -0.1570618118172361, -0.464960739991988, 0.69659695495191, -0.19589005679866606, -0.1219410681137735, 0.95229044665 ...
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('b22400a8-c952-4891-85ce-5aecedae98b2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childLi

# %%
df3= df2.loc['SEASON 5',:]

# %%
df3
# Out:
# SEASONS
# MATCHES PLAYED           22.000000
# WINS                     10.000000
# DRAWS                     0.000000
# LOSSES                   12.000000
# FINISHING POSITION        4.000000
# TOTAL RAIDS             963.000000
# SUCCESSFUL RAIDS        322.000000
# UNSUCCESSFUL RAID       219.000000
# EMPTY RAIDS             422.000000
# SUCCESS RAID %            0.440000
# NO. OF SUPER RAIDS       10.000000
# RAID TOUCH POINTS       298.000000
# RAID BONUS POINTS       121.000000
# TOTAL RAID POINTS       419.000000
# TOTAL TACKLES           539.000000
# SUCCESSFUL TACKLES      176.000000
# UNSUCCESFUL TACKLES     363.000000
# SUCCESSFUL TACKLE %       0.370000
# NO. OF SUPER TACKLES     26.000000
# ALL OUTS INFLICTED       21.000000
# TOTAL ALL OUT POINTS     42.000000
# TOTAL DEFENCE POINTS    202.000000
# WIN%                      0.454545
# DRAW%                     0.000000
# LOSS%                     0.545455
# WIN-LOSS%                 0.833333
# UNSUCCESSFUL RAID%        0.227414
# EMPTY RAID%               0.438214
# AVG_RAID_TOUCH_POINT     13.545455
# AVG_RAID_BONUS_POINT      5.500000
# UNSUCCESSFUL TACKLE%      0.673469
# AVG_ALL_OUTS              0.954545
# Name: SEASON 5, dtype: float64

# %%
df3.iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="a65ae1ed-f784-450e-9ddf-8e4304a71681" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a65ae1ed-f784-450e-9ddf-8e4304a71681")) {
#                     Plotly.newPlot(
#                         'a65ae1ed-f784-450e-9ddf-8e4304a71681',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "SEASON 5", "orientation": "v", "text": "", "type": "bar", "uid": "bd487140-902a-442a-a845-c17b73dc43b7", "x": ["MATCHES PLAYED", "WINS", "DRAWS", "LOSSES", "FINISHING POSITION", "TOTAL RAIDS", "SUCCESSFUL RAIDS", "UNSUCCESSFUL RAID", "EMPTY RAIDS", "SUCCESS RAID %", "NO. OF SUPER RAIDS", "RAID TOUCH POINTS", "RAID BONUS POINTS", "TOTAL RAID POINTS", "TOTAL TACKLES", "SUCCESSFUL TACKLES", "UNSUCCESFUL TACKLES", "SUCCESSFUL TACKLE %", "NO. OF SUPER TACKLES", "ALL OUTS INFLICTED", "TOTAL ALL OUT POINTS", "TOTAL DEFENCE POINTS", "WIN%", "DRAW%", "LOSS%", "WIN-LOSS%", "UNSUCCESSFUL RAID%", "EMPTY RAID%", "AVG_RAID_TOUCH_POINT", "AVG_RAID_BONUS_POINT", "UNSUCCESSFUL TACKLE%", "AVG_ALL_OUTS"], "y": [22.0, 10.0, 0.0, 12.0, 4.0, 963.0, 322.0, 219.0, 422.0, 0.44, 10.0, 298.0, 121.0, 419.0, 539.0, 176.0, 363.0, 0.37, 26.0, 21.0, 42.0, 202.0, 0.45454545454545453, 0.0, 0.5454545454545454, 0.8333333333333334, 0.22741433021806853, 0.43821391484942884, 13.545454545454545, 5.5, 0.673469387755102, 0.9545454545454546]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('a65ae1ed-f784-450e-9ddf-8e4304a71681');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
df4 =df6.drop('FINISHING POSITION',axis=1)
df4 =df4.drop(['SEASON 7'])
df4
# Out:
# SEASONS   TOTAL RAIDS  SUCCESS RAID %  SUCCESSFUL TACKLE %  \
# OVERALL        5187.0            0.43                 0.46
# SEASON 6        978.0            0.47                 0.52
# SEASON 5        963.0            0.44                 0.37
# SEASON 4        594.0            0.38                 0.41
# SEASON 3        685.0            0.37                 0.51
# SEASON 2        697.0            0.34                 0.54
# SEASON 1        624.0            0.56                 0.38
#
# SEASONS   NO. OF SUPER TACKLES  TOTAL DEFENCE POINTS      WIN%     DRAW%  \
# OVERALL                  102.0                1293.0  0.617886  0.056911
# SEASON 6                  15.0                 289.0  0.652174  0.086957
# SEASON 5                  26.0                 202.0  0.454545  0.000000
# SEASON 4                  11.0                 121.0  0.500000  0.071429
# SEASON 3                   6.0                 169.0  0.812500  0.000000
# SEASON 2                  16.0                 196.0  0.875000  0.000000
# SEASON 1                  12.0                 157.0  0.562500  0.187500
#
# SEASONS      LOSS%  WIN-LOSS%  UNSUCCESSFUL RAID%  EMPTY RAID%  \
# OVERALL   0.325203   1.900000            0.216117     0.445922
# SEASON 6  0.260870   2.500000            0.200409     0.419223
# SEASON 5  0.545455   0.833333            0.227414     0.438214
# SEASON 4  0.428571   1.166667            0.220539     0.462963
# SEASON 3  0.187500   4.333333            0.202920     0.496350
# SEASON 2  0.125000   7.000000            0.220947     0.510760
# SEASON 1  0.250000   2.250000            0.214744     0.352564
#
# SEASONS   AVG_RAID_TOUCH_POINT  AVG_RAID_BONUS_POINT  UNSUCCESSFUL TACKLE%  \
# OVERALL              14.032520              3.918699              0.577849
# SEASON 6             16.173913              3.782609              0.508961
# SEASON 5             13.545455              5.500000              0.673469
# SEASON 4             11.714286              4.500000              0.624573
# SEASON 3             13.187500              2.625000              0.504559
# SEASON 2             12.875000              1.937500              0.505495
# SEASON 1             16.375000              5.312500              0.645477
#
# SEASONS   AVG_ALL_OUTS
# OVERALL       1.357724
# SEASON 6      1.782609
# SEASON 5      0.954545
# SEASON 4      1.071429
# SEASON 3      1.687500
# SEASON 2      1.250000
# SEASON 1      1.312500

# %%
df5 = df6['FINISHING POSITION']
df5 = df5.drop(['SEASON 7'],axis=0)
#df5['FINISHING POSITION'] = df['FINISHING POSITION'].fillna(0)
df5
# Out:
# OVERALL     0.0
# SEASON 6    2.0
# SEASON 5    4.0
# SEASON 4    4.0
# SEASON 3    1.0
# SEASON 2    1.0
# SEASON 1    2.0
# Name: FINISHING POSITION, dtype: float64

# %%
df4
# Out:
# SEASONS   TOTAL RAIDS  SUCCESS RAID %  SUCCESSFUL TACKLE %  \
# OVERALL        5187.0            0.43                 0.46
# SEASON 6        978.0            0.47                 0.52
# SEASON 5        963.0            0.44                 0.37
# SEASON 4        594.0            0.38                 0.41
# SEASON 3        685.0            0.37                 0.51
# SEASON 2        697.0            0.34                 0.54
# SEASON 1        624.0            0.56                 0.38
#
# SEASONS   NO. OF SUPER TACKLES  TOTAL DEFENCE POINTS      WIN%     DRAW%  \
# OVERALL                  102.0                1293.0  0.617886  0.056911
# SEASON 6                  15.0                 289.0  0.652174  0.086957
# SEASON 5                  26.0                 202.0  0.454545  0.000000
# SEASON 4                  11.0                 121.0  0.500000  0.071429
# SEASON 3                   6.0                 169.0  0.812500  0.000000
# SEASON 2                  16.0                 196.0  0.875000  0.000000
# SEASON 1                  12.0                 157.0  0.562500  0.187500
#
# SEASONS      LOSS%  WIN-LOSS%  UNSUCCESSFUL RAID%  EMPTY RAID%  \
# OVERALL   0.325203   1.900000            0.216117     0.445922
# SEASON 6  0.260870   2.500000            0.200409     0.419223
# SEASON 5  0.545455   0.833333            0.227414     0.438214
# SEASON 4  0.428571   1.166667            0.220539     0.462963
# SEASON 3  0.187500   4.333333            0.202920     0.496350
# SEASON 2  0.125000   7.000000            0.220947     0.510760
# SEASON 1  0.250000   2.250000            0.214744     0.352564
#
# SEASONS   AVG_RAID_TOUCH_POINT  AVG_RAID_BONUS_POINT  UNSUCCESSFUL TACKLE%  \
# OVERALL              14.032520              3.918699              0.577849
# SEASON 6             16.173913              3.782609              0.508961
# SEASON 5             13.545455              5.500000              0.673469
# SEASON 4             11.714286              4.500000              0.624573
# SEASON 3             13.187500              2.625000              0.504559
# SEASON 2             12.875000              1.937500              0.505495
# SEASON 1             16.375000              5.312500              0.645477
#
# SEASONS   AVG_ALL_OUTS
# OVERALL       1.357724
# SEASON 6      1.782609
# SEASON 5      0.954545
# SEASON 4      1.071429
# SEASON 3      1.687500
# SEASON 2      1.250000
# SEASON 1      1.312500

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
X = df4
y= df5
clf = ExtraTreesClassifier(n_estimators=50)
clf = clf.fit(X, y)
clf.feature_importances_  
model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X)
X_new.shape
# Out:
# (7, 8)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['FEATURES','Score']  #naming the dataframe columns
print(featureScores.nlargest(5,'Score'))  #print 10 best features
# Out:
#                 FEATURES         Score
# 0            TOTAL RAIDS  12114.804533
# 4   TOTAL DEFENCE POINTS   3024.416564
# 3   NO. OF SUPER TACKLES    247.452128
# 8              WIN-LOSS%      8.430060
# 12  AVG_RAID_BONUS_POINT      2.154806

# %%
#Feature Importance 
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
# %matplotlib inline

model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers

#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# D:\anaconda\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning:
#
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
# [0.07259259 0.08166667 0.0162037  0.00648148 0.04861111 0.10759259
#  0.10101852 0.09675926 0.         0.05462963 0.10648148 0.0875
#  0.02916667 0.09351852 0.09777778]

# %%
cols = list(X.columns)
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model,12)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,y)  
#Fitting the data to model
model.fit(X_rfe,y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# Index(['SUCCESSFUL TACKLE %', 'NO. OF SUPER TACKLES', 'WIN%', 'DRAW%', 'LOSS%',
#        'UNSUCCESSFUL RAID%', 'EMPTY RAID%', 'AVG_RAID_TOUCH_POINT',
#        'AVG_RAID_BONUS_POINT', 'UNSUCCESSFUL TACKLE%', 'AVG_ALL_OUTS',
#        'WIN-LOSS%'],
#       dtype='object')

# %%
X_features = df4.filter(['SUCCESSFUL TACKLE %', 'NO. OF SUPER TACKLES', 'WIN%', 'DRAW%', 'LOSS%',
       'UNSUCCESSFUL RAID%', 'EMPTY RAID%', 'AVG_RAID_TOUCH_POINT',
       'AVG_RAID_BONUS_POINT', 'UNSUCCESSFUL TACKLE%', 'AVG_ALL_OUTS',
       'WIN-LOSS%'],axis=1)
X_features.shape
# Out:
# (7, 12)

# %%
import os
os.environ['KERAS_BACKEND'] = 'theano'
import keras as ks
# Out:
# Using Theano backend.
# You can find the C code in this temporary file: C:\Users\ANINDA~1.BHA\AppData\Local\Temp\theano_compilation_error_pvekssrp
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# D:\anaconda\lib\site-packages\theano\gof\lazylinker_c.py in <module>()
#      80                     version,
# ---> 81                     actual_version, force_compile, _need_reload))
#      82 except ImportError:
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.211, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# D:\anaconda\lib\site-packages\theano\gof\lazylinker_c.py in <module>()
#     104                         version,
# --> 105                         actual_version, force_compile, _need_reload))
#     106         except ImportError:
#
# ImportError: Version check of the existing lazylinker compiled file. Looking for version 0.211, but found None. Extra debug information: force_compile=False, _need_reload=True
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-26-e42f4e18d2a5> in <module>()
#       1 import os
#       2 os.environ['KERAS_BACKEND'] = 'theano'
# ----> 3 import keras as ks
#
# D:\anaconda\lib\site-packages\keras\__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# D:\anaconda\lib\site-packages\keras\utils\__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# D:\anaconda\lib\site-packages\keras\utils\conv_utils.py in <module>()
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# D:\anaconda\lib\site-packages\keras\backend\__init__.py in <module>()
#      84 elif _BACKEND == 'theano':
#      85     sys.stderr.write('Using Theano backend.\n')
# ---> 86     from .theano_backend import *
#      87 elif _BACKEND == 'tensorflow':
#      88     sys.stderr.write('Using TensorFlow backend.\n')
#
# D:\anaconda\lib\site-packages\keras\backend\theano_backend.py in <module>()
#       5 from collections import defaultdict
#       6 from contextlib import contextmanager
# ----> 7 import theano
#       8 from theano import tensor as T
#       9 from theano.sandbox.rng_mrg import MRG_RandomStreams as RandomStreams
#
# D:\anaconda\lib\site-packages\theano\__init__.py in <module>()
#     108     object2, utils)
#     109
# --> 110 from theano.compile import (
#     111     SymbolicInput, In,
#     112     SymbolicOutput, Out,
#
# D:\anaconda\lib\site-packages\theano\compile\__init__.py in <module>()
#      10 from theano.compile.function_module import *
#      11
# ---> 12 from theano.compile.mode import *
#      13
#      14 from theano.compile.io import *
#
# D:\anaconda\lib\site-packages\theano\compile\mode.py in <module>()
#       9 import theano
#      10 from theano import gof
# ---> 11 import theano.gof.vm
#      12 from theano import config
#      13 from six import string_types
#
# D:\anaconda\lib\site-packages\theano\gof\vm.py in <module>()
#     672     if not theano.config.cxx:
#     673         raise theano.gof.cmodule.MissingGXX('lazylinker will not be imported if theano.config.cxx is not set.')
# --> 674     from . import lazylinker_c
#     675
#     676     class CVM(lazylinker_c.CLazyLinker, VM):
#
# D:\anaconda\lib\site-packages\theano\gof\lazylinker_c.py in <module>()
#     138             args = cmodule.GCC_compiler.compile_args()
#     139             cmodule.GCC_compiler.compile_str(dirname, code, location=loc,
# --> 140                                              preargs=args)
#     141             # Save version into the __init__.py file.
#     142             init_py = os.path.join(loc, '__init__.py')
#
# D:\anaconda\lib\site-packages\theano\gof\cmodule.py in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2394             # difficult to read.
#    2395             raise Exception('Compilation failed (return status=%s): %s' %
# -> 2396                             (status, compile_stderr.replace('\n', '. ')))
#    2397         elif config.cmodule.compilation_warning and compile_stderr:
#    2398             # Print errors just below the command line.
#
# .

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X_features, y, epochs=150, batch_size=10)

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X_features, y)
print('Accuracy: %.2f' % (accuracy*100))

# %%
f_select = ['SUCCESSFUL TACKLE %', 'NO. OF SUPER TACKLES', 'WIN%', 'DRAW%', 'LOSS%',
       'UNSUCCESSFUL RAID%', 'EMPTY RAID%', 'AVG_RAID_TOUCH_POINT',
       'AVG_RAID_BONUS_POINT', 'UNSUCCESSFUL TACKLE%', 'AVG_ALL_OUTS',
       'WIN-LOSS%']
f_select
# Out:
# ['SUCCESSFUL TACKLE %',
#  'NO. OF SUPER TACKLES',
#  'WIN%',
#  'DRAW%',
#  'LOSS%',
#  'UNSUCCESSFUL RAID%',
#  'EMPTY RAID%',
#  'AVG_RAID_TOUCH_POINT',
#  'AVG_RAID_BONUS_POINT',
#  'UNSUCCESSFUL TACKLE%',
#  'AVG_ALL_OUTS',
#  'WIN-LOSS%']

# %%
#Using PCA to transform and decouple the dataset defined by the selected features
from sklearn.decomposition import PCA
pca = PCA()  
XX = pca.fit_transform(X[f_select]) # XX is out new training matrix that has two basis vectors
XX
# Out:
# array([[ 7.51482184e+01,  3.10711509e-01, -4.25920292e-02,
#          1.02849226e-01,  2.35753825e-02, -3.90239434e-03,
#          4.54950962e-15],
#        [-1.18486037e+01, -9.15070572e-01, -2.00788775e+00,
#          6.82708874e-01, -8.27115970e-02, -2.85252395e-02,
#          4.54950962e-15],
#        [-8.20945513e-01, -2.38717022e+00,  1.06871851e+00,
#         -4.34824720e-01, -8.72983382e-02,  6.75097619e-02,
#          4.54950962e-15],
#        [-1.58292219e+01, -1.35002484e+00,  2.73199760e+00,
#          1.82106040e-01,  2.90353105e-02, -6.94887020e-02,
#          4.54950962e-15],
#        [-2.08825811e+01,  1.80676566e+00,  3.55945378e-01,
#          5.12265641e-01,  7.36464887e-02,  7.75604321e-02,
#          4.54950962e-15],
#        [-1.09274892e+01,  4.55619088e+00, -7.37653133e-02,
#         -4.92201982e-01, -4.51274054e-02, -2.81119703e-02,
#          4.54950962e-15],
#        [-1.48393771e+01, -2.02140242e+00, -2.03241639e+00,
#         -5.52903080e-01,  8.88801589e-02, -1.50418878e-02,
#          4.54950962e-15]])

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
df6
# Out:
# SEASONS   FINISHING POSITION  TOTAL RAIDS  SUCCESS RAID %  \
# OVERALL                  0.0       5187.0            0.43
# SEASON 7                 5.0        646.0            0.41
# SEASON 6                 2.0        978.0            0.47
# SEASON 5                 4.0        963.0            0.44
# SEASON 4                 4.0        594.0            0.38
# SEASON 3                 1.0        685.0            0.37
# SEASON 2                 1.0        697.0            0.34
# SEASON 1                 2.0        624.0            0.56
#
# SEASONS   SUCCESSFUL TACKLE %  NO. OF SUPER TACKLES  TOTAL DEFENCE POINTS  \
# OVERALL                  0.46                 102.0                1293.0
# SEASON 7                 0.48                  16.0                 159.0
# SEASON 6                 0.52                  15.0                 289.0
# SEASON 5                 0.37                  26.0                 202.0
# SEASON 4                 0.41                  11.0                 121.0
# SEASON 3                 0.51                   6.0                 169.0
# SEASON 2                 0.54                  16.0                 196.0
# SEASON 1                 0.38                  12.0                 157.0
#
# SEASONS       WIN%     DRAW%     LOSS%  WIN-LOSS%  UNSUCCESSFUL RAID%  \
# OVERALL   0.617886  0.056911  0.325203   1.900000            0.216117
# SEASON 7  0.500000  0.062500  0.437500   1.142857            0.229102
# SEASON 6  0.652174  0.086957  0.260870   2.500000            0.200409
# SEASON 5  0.454545  0.000000  0.545455   0.833333            0.227414
# SEASON 4  0.500000  0.071429  0.428571   1.166667            0.220539
# SEASON 3  0.812500  0.000000  0.187500   4.333333            0.202920
# SEASON 2  0.875000  0.000000  0.125000   7.000000            0.220947
# SEASON 1  0.562500  0.187500  0.250000   2.250000            0.214744
#
# SEASONS   EMPTY RAID%  AVG_RAID_TOUCH_POINT  AVG_RAID_BONUS_POINT  \
# OVERALL      0.445922             14.032520              3.918699
# SEASON 7     0.448916             13.312500              3.312500
# SEASON 6     0.419223             16.173913              3.782609
# SEASON 5     0.438214             13.545455              5.500000
# SEASON 4     0.462963             11.714286              4.500000
# SEASON 3     0.496350             13.187500              2.625000
# SEASON 2     0.510760             12.875000              1.937500
# SEASON 1     0.352564             16.375000              5.312500
#
# SEASONS   UNSUCCESSFUL TACKLE%  AVG_ALL_OUTS
# OVERALL               0.577849      1.357724
# SEASON 7              0.565868      1.375000
# SEASON 6              0.508961      1.782609
# SEASON 5              0.673469      0.954545
# SEASON 4              0.624573      1.071429
# SEASON 3              0.504559      1.687500
# SEASON 2              0.505495      1.250000
# SEASON 1              0.645477      1.312500

# %%
X_train = X
y_train =y 
X_test = df6.drop(['SEASON 6','SEASON 5','SEASON 4','SEASON 3','SEASON 2','SEASON 1','OVERALL'],axis=0)
X_test = X_test.drop(['FINISHING POSITION'], axis=1)
y_test = df6['FINISHING POSITION']
y_test = y_test.drop(['SEASON 6','SEASON 5','SEASON 4','SEASON 3','SEASON 2','SEASON 1','OVERALL'],axis=0)

# %%
X_test
# Out:
# SEASONS   TOTAL RAIDS  SUCCESS RAID %  SUCCESSFUL TACKLE %  \
# SEASON 7        646.0            0.41                 0.48
#
# SEASONS   NO. OF SUPER TACKLES  TOTAL DEFENCE POINTS  WIN%   DRAW%   LOSS%  \
# SEASON 7                  16.0                 159.0   0.5  0.0625  0.4375
#
# SEASONS   WIN-LOSS%  UNSUCCESSFUL RAID%  EMPTY RAID%  AVG_RAID_TOUCH_POINT  \
# SEASON 7   1.142857            0.229102     0.448916               13.3125
#
# SEASONS   AVG_RAID_BONUS_POINT  UNSUCCESSFUL TACKLE%  AVG_ALL_OUTS
# SEASON 7                3.3125              0.565868         1.375

# %%
y_test
# Out:
# SEASON 7    5.0
# Name: FINISHING POSITION, dtype: float64

# %%
# machine learning
from sklearn.svm import SVC
from sklearn import preprocessing
#import fancyimpute
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

#  Metrics
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score

# Models
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=True) # Change verbose to True if you want to see it train
# Out:
# [14:24:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1.92531	validation_1-rmse:4.4375
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 50 rounds.
# [1]	validation_0-rmse:1.80053	validation_1-rmse:4.37969
# [2]	validation_0-rmse:1.681	validation_1-rmse:4.17363
# [3]	validation_0-rmse:1.56944	validation_1-rmse:3.9813
# [4]	validation_0-rmse:1.46532	validation_1-rmse:3.8018
# [5]	validation_0-rmse:1.36816	validation_1-rmse:3.63426
# [6]	validation_0-rmse:1.27749	validation_1-rmse:3.47789
# [7]	validation_0-rmse:1.19287	validation_1-rmse:3.33195
# [8]	validation_0-rmse:1.11391	validation_1-rmse:3.19574
# [9]	validation_0-rmse:1.04024	validation_1-rmse:3.0686
# [10]	validation_0-rmse:0.97149	validation_1-rmse:2.94995
# [11]	validation_0-rmse:0.907347	validation_1-rmse:2.8392
# [12]	validation_0-rmse:0.847504	validation_1-rmse:2.73584
# [13]	validation_0-rmse:0.791675	validation_1-rmse:2.63937
# [14]	validation_0-rmse:0.739596	validation_1-rmse:2.54932
# [15]	validation_0-rmse:0.69102	validation_1-rmse:2.46529
# [16]	validation_0-rmse:0.645715	validation_1-rmse:2.38685
# [17]	validation_0-rmse:0.603466	validation_1-rmse:2.31364
# [18]	validation_0-rmse:0.564073	validation_1-rmse:2.24532
# [19]	validation_0-rmse:0.527348	validation_1-rmse:2.18155
# [20]	validation_0-rmse:0.493117	validation_1-rmse:2.12203
# [21]	validation_0-rmse:0.461216	validation_1-rmse:2.06647
# [22]	validation_0-rmse:0.431495	validation_1-rmse:2.01463
# [23]	validation_0-rmse:0.403812	validation_1-rmse:1.96623
# [24]	validation_0-rmse:0.377988	validation_1-rmse:1.92107
# [25]	validation_0-rmse:0.353853	validation_1-rmse:1.87891
# [26]	validation_0-rmse:0.331297	validation_1-rmse:1.83957
# [27]	validation_0-rmse:0.310214	validation_1-rmse:1.80285
# [28]	validation_0-rmse:0.290507	validation_1-rmse:1.76858
# [29]	validation_0-rmse:0.272086	validation_1-rmse:1.73659
# [30]	validation_0-rmse:0.254865	validation_1-rmse:1.70673
# [31]	validation_0-rmse:0.23878	validation_1-rmse:1.67887
# [32]	validation_0-rmse:0.223721	validation_1-rmse:1.65286
# [33]	validation_0-rmse:0.209693	validation_1-rmse:1.62858
# [34]	validation_0-rmse:0.196566	validation_1-rmse:1.60593
# [35]	validation_0-rmse:0.184283	validation_1-rmse:1.58478
# [36]	validation_0-rmse:0.172788	validation_1-rmse:1.56505
# [37]	validation_0-rmse:0.160146	validation_1-rmse:1.54587
# [38]	validation_0-rmse:0.150165	validation_1-rmse:1.52873
# [39]	validation_0-rmse:0.139176	validation_1-rmse:1.51205
# [40]	validation_0-rmse:0.130501	validation_1-rmse:1.49716
# [41]	validation_0-rmse:0.120966	validation_1-rmse:1.48269
# [42]	validation_0-rmse:0.113429	validation_1-rmse:1.46976
# [43]	validation_0-rmse:0.105157	validation_1-rmse:1.45721
# [44]	validation_0-rmse:0.097513	validation_1-rmse:1.4456
# [45]	validation_0-rmse:0.091416	validation_1-rmse:1.43514
# [46]	validation_0-rmse:0.085724	validation_1-rmse:1.42538
# [47]	validation_0-rmse:0.079487	validation_1-rmse:1.41591
# [48]	validation_0-rmse:0.073723	validation_1-rmse:1.40716
# D:\anaconda\lib\site-packages\xgboost\core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
# [49]	validation_0-rmse:0.069122	validation_1-rmse:1.39926
# [50]	validation_0-rmse:0.064112	validation_1-rmse:1.39165
# [51]	validation_0-rmse:0.060118	validation_1-rmse:1.38479
# [52]	validation_0-rmse:0.055772	validation_1-rmse:1.37819
# [53]	validation_0-rmse:0.052297	validation_1-rmse:1.37223
# [54]	validation_0-rmse:0.048518	validation_1-rmse:1.36648
# [55]	validation_0-rmse:0.045498	validation_1-rmse:1.3613
# [56]	validation_0-rmse:0.04222	validation_1-rmse:1.35632
# [57]	validation_0-rmse:0.039594	validation_1-rmse:1.35182
# [58]	validation_0-rmse:0.036744	validation_1-rmse:1.34749
# [59]	validation_0-rmse:0.034459	validation_1-rmse:1.34357
# [60]	validation_0-rmse:0.031986	validation_1-rmse:1.33982
# [61]	validation_0-rmse:0.0297	validation_1-rmse:1.33634
# [62]	validation_0-rmse:0.027849	validation_1-rmse:1.33317
# [63]	validation_0-rmse:0.026119	validation_1-rmse:1.33021
# [64]	validation_0-rmse:0.024253	validation_1-rmse:1.32738
# [65]	validation_0-rmse:0.022528	validation_1-rmse:1.32476
# [66]	validation_0-rmse:0.020934	validation_1-rmse:1.32234
# [67]	validation_0-rmse:0.019626	validation_1-rmse:1.3201
# [68]	validation_0-rmse:0.018408	validation_1-rmse:1.31801
# [69]	validation_0-rmse:0.017105	validation_1-rmse:1.31603
# [70]	validation_0-rmse:0.016043	validation_1-rmse:1.31421
# [71]	validation_0-rmse:0.014912	validation_1-rmse:1.3125
# [72]	validation_0-rmse:0.013988	validation_1-rmse:1.31092
# [73]	validation_0-rmse:0.013004	validation_1-rmse:1.30943
# [74]	validation_0-rmse:0.012199	validation_1-rmse:1.30805
# [75]	validation_0-rmse:0.011344	validation_1-rmse:1.30676
# [76]	validation_0-rmse:0.010642	validation_1-rmse:1.30556
# [77]	validation_0-rmse:0.0099	validation_1-rmse:1.30443
# [78]	validation_0-rmse:0.009289	validation_1-rmse:1.30339
# [79]	validation_0-rmse:0.008715	validation_1-rmse:1.30241
# [80]	validation_0-rmse:0.008109	validation_1-rmse:1.3015
# [81]	validation_0-rmse:0.007549	validation_1-rmse:1.30065
# [82]	validation_0-rmse:0.007084	validation_1-rmse:1.29986
# [83]	validation_0-rmse:0.006648	validation_1-rmse:1.29912
# [84]	validation_0-rmse:0.00619	validation_1-rmse:1.29843
# [85]	validation_0-rmse:0.005768	validation_1-rmse:1.29779
# [86]	validation_0-rmse:0.005412	validation_1-rmse:1.29719
# [87]	validation_0-rmse:0.00508	validation_1-rmse:1.29663
# [88]	validation_0-rmse:0.004734	validation_1-rmse:1.29611
# [89]	validation_0-rmse:0.004444	validation_1-rmse:1.29562
# [90]	validation_0-rmse:0.004143	validation_1-rmse:1.29517
# [91]	validation_0-rmse:0.003866	validation_1-rmse:1.29475
# [92]	validation_0-rmse:0.003628	validation_1-rmse:1.29435
# [93]	validation_0-rmse:0.003406	validation_1-rmse:1.29398
# [94]	validation_0-rmse:0.003179	validation_1-rmse:1.29364
# [95]	validation_0-rmse:0.002985	validation_1-rmse:1.29331
# [96]	validation_0-rmse:0.002787	validation_1-rmse:1.29302
# [97]	validation_0-rmse:0.002617	validation_1-rmse:1.29273
# [98]	validation_0-rmse:0.002458	validation_1-rmse:1.29246
# [99]	validation_0-rmse:0.002296	validation_1-rmse:1.29222
# [100]	validation_0-rmse:0.002146	validation_1-rmse:1.292
# [101]	validation_0-rmse:0.002021	validation_1-rmse:1.29179
# [102]	validation_0-rmse:0.001905	validation_1-rmse:1.29158
# [103]	validation_0-rmse:0.001797	validation_1-rmse:1.2914
# [104]	validation_0-rmse:0.001679	validation_1-rmse:1.29122
# [105]	validation_0-rmse:0.001585	validation_1-rmse:1.29106
# [106]	validation_0-rmse:0.001482	validation_1-rmse:1.29091
# [107]	validation_0-rmse:0.001399	validation_1-rmse:1.29076
# [108]	validation_0-rmse:0.001309	validation_1-rmse:1.29063
# [109]	validation_0-rmse:0.001226	validation_1-rmse:1.29051
# [110]	validation_0-rmse:0.001148	validation_1-rmse:1.2904
# [111]	validation_0-rmse:0.001077	validation_1-rmse:1.2903
# [112]	validation_0-rmse:0.001011	validation_1-rmse:1.2902
# [113]	validation_0-rmse:0.000953	validation_1-rmse:1.2901
# [114]	validation_0-rmse:0.000915	validation_1-rmse:1.29001
# [115]	validation_0-rmse:0.00086	validation_1-rmse:1.28993
# [116]	validation_0-rmse:0.000824	validation_1-rmse:1.28989
# [117]	validation_0-rmse:0.000792	validation_1-rmse:1.28982
# [118]	validation_0-rmse:0.00076	validation_1-rmse:1.28978
# [119]	validation_0-rmse:0.000731	validation_1-rmse:1.2898
# [120]	validation_0-rmse:0.000704	validation_1-rmse:1.28977
# [121]	validation_0-rmse:0.000677	validation_1-rmse:1.28971
# [122]	validation_0-rmse:0.000652	validation_1-rmse:1.28968
# [123]	validation_0-rmse:0.000628	validation_1-rmse:1.28962
# [124]	validation_0-rmse:0.000626	validation_1-rmse:1.28961
# [125]	validation_0-rmse:0.000625	validation_1-rmse:1.28961
# [126]	validation_0-rmse:0.000624	validation_1-rmse:1.2896
# [127]	validation_0-rmse:0.000623	validation_1-rmse:1.28959
# [128]	validation_0-rmse:0.000623	validation_1-rmse:1.28959
# [129]	validation_0-rmse:0.000622	validation_1-rmse:1.28958
# [130]	validation_0-rmse:0.000622	validation_1-rmse:1.28958
# [131]	validation_0-rmse:0.000621	validation_1-rmse:1.28957
# [132]	validation_0-rmse:0.000621	validation_1-rmse:1.28957
# [133]	validation_0-rmse:0.000621	validation_1-rmse:1.28956
# [134]	validation_0-rmse:0.000621	validation_1-rmse:1.28956
# [135]	validation_0-rmse:0.00062	validation_1-rmse:1.28956
# [136]	validation_0-rmse:0.00062	validation_1-rmse:1.28955
# [137]	validation_0-rmse:0.00062	validation_1-rmse:1.28955
# [138]	validation_0-rmse:0.00062	validation_1-rmse:1.28955
# [139]	validation_0-rmse:0.00062	validation_1-rmse:1.28955
# [140]	validation_0-rmse:0.00062	validation_1-rmse:1.28954
# [141]	validation_0-rmse:0.00062	validation_1-rmse:1.28954
# [142]	validation_0-rmse:0.00062	validation_1-rmse:1.28954
# [143]	validation_0-rmse:0.00062	validation_1-rmse:1.28954
# [144]	validation_0-rmse:0.00062	validation_1-rmse:1.28954
# [145]	validation_0-rmse:0.00062	validation_1-rmse:1.28954
# [146]	validation_0-rmse:0.00062	validation_1-rmse:1.28954
# [147]	validation_0-rmse:0.00062	validation_1-rmse:1.28954
# [148]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [149]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [150]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [151]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [152]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [153]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [154]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [155]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [156]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [157]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [158]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [159]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [160]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [161]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [162]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [163]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [164]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [165]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [166]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [167]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [168]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [169]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [170]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [171]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [172]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [173]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [174]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [175]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [176]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [177]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [178]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [179]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [180]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [181]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [182]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [183]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [184]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [185]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [186]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [187]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [188]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [189]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [190]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [191]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [192]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [193]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [194]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [195]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [196]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [197]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [198]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [199]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [200]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [201]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [202]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [203]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [204]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [205]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [206]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [207]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [208]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [209]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [210]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [211]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [212]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [213]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [214]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [215]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [216]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# [217]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# Stopping. Best iteration:
# [167]	validation_0-rmse:0.00062	validation_1-rmse:1.28953
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
pred  = pd.DataFrame()
pred['MW_Prediction'] = reg.predict(X_test)

# %%
pred['MW_Prediction']
# Out:
# 0    3.710475
# Name: MW_Prediction, dtype: float32

# %%
predict = reg.predict(X_test)
predictions = [round(value) for value in predict]
predictions
# Out:
# [4.0]

# %% [markdown]
# ## Finding the win-loss% of a team for Season 7

# %%
df6.loc['SEASON 7','WIN-LOSS%']
# Out:
# 1.1428571428571428

# %% [markdown]
# ## Finding the successful Raid %(successful raid/ total raid) for season 7

# %%
SUCC_RAID =df2.loc['SEASON 7','SUCCESSFUL RAIDS']
TOT_RAID = df2.loc['SEASON 7','TOTAL RAIDS']

SUCC_RAID_PERC = SUCC_RAID/TOT_RAID
SUCC_RAID_PERC
# Out:
# 0.3219814241486068

# %% [markdown]
# ## Finding the OVERALL successful Raid %(successful raid/ total raid) of a team

# %%
SUCC_RAID_OV =df2.loc['OVERALL','SUCCESSFUL RAIDS']
TOT_RAID_OV = df2.loc['OVERALL','TOTAL RAIDS']

SUCC_RAID_PERC_OV = SUCC_RAID_OV/TOT_RAID_OV
SUCC_RAID_PERC_OV
# Out:
# 0.33796028532870637

# %% [markdown]
# ## Finding the Super-performance total of the team

# %%
SUPER_RAIDS = df2.loc['SEASON 7','NO. OF SUPER RAIDS']
SUPER_TACKLES = df2.loc['SEASON 7','NO. OF SUPER TACKLES']
All_OUTS_INFLICTED = df2.loc['SEASON 7','ALL OUTS INFLICTED']
All_OUTS_CONCEDED = 22

SPT = SUPER_RAIDS+SUPER_TACKLES+All_OUTS_INFLICTED-All_OUTS_CONCEDED
SPT
# Out:
# 23.0
